# %%
# Dependencies
import pandas as pd
import numpy as np
from matplotlib.dates import date2num
import datetime
import matplotlib.pyplot as plt
import requests
import time
import random

# %%
# Name of the CSV file
csv_path= "Resources/obesity_men_vs_women.csv"
men_and_women_df = pd.read_csv(csv_path)

# Drop the rows that have been added with no data or partial data
new_men_and_women = men_and_women_df.dropna(inplace = True)
men_and_women_df.tail()
# Out:
#          Entity Code  Year  Obese Women (%)  Obese Men (%)  Total population
# 20802  Zimbabwe  ZWE  2009             22.2            3.6        12473992.0
# 20803  Zimbabwe  ZWE  2010             22.6            3.7        12571454.0
# 20804  Zimbabwe  ZWE  2011             23.0            3.9        12754378.0
# 20805  Zimbabwe  ZWE  2012             23.5            4.0        13013678.0
# 20806  Zimbabwe  ZWE  2013             23.9            4.2        13327925.0

# %%
# To sort from highest to lowest, ascending=False must be passed in
year_df = men_and_women_df.sort_values('Total population')
year_df.head(10)
# Out:
#       Entity Code  Year  Obese Women (%)  Obese Men (%)  Total population
# 13731   Niue  NIU  2013             53.2           42.1            1346.0
# 13730   Niue  NIU  2012             52.5           41.2            1385.0
# 13729   Niue  NIU  2011             51.8           40.3            1426.0
# 13728   Niue  NIU  2010             51.1           39.4            1468.0
# 13727   Niue  NIU  2009             50.4           38.5            1511.0
# 13726   Niue  NIU  2008             49.8           37.6            1555.0
# 13725   Niue  NIU  2007             49.1           36.7            1598.0
# 13724   Niue  NIU  2006             48.4           35.8            1643.0
# 13723   Niue  NIU  2005             47.7           35.0            1686.0
# 13722   Niue  NIU  2004             47.0           34.2            1728.0

# %%
men_and_women_df.loc[:,'Entity': 'Total population']
# Out:
#             Entity Code  Year  Obese Women (%)  Obese Men (%)  \
# 29     Afghanistan  AFG  1975              0.8            0.2
# 30     Afghanistan  AFG  1976              0.8            0.2
# 31     Afghanistan  AFG  1977              0.9            0.2
# 32     Afghanistan  AFG  1978              0.9            0.2
# 33     Afghanistan  AFG  1979              1.0            0.3
# 34     Afghanistan  AFG  1980              1.1            0.3
# 35     Afghanistan  AFG  1981              1.1            0.3
# 36     Afghanistan  AFG  1982              1.2            0.3
# 37     Afghanistan  AFG  1983              1.3            0.4
# 38     Afghanistan  AFG  1984              1.4            0.4
# 39     Afghanistan  AFG  1985              1.5            0.4
# 40     Afghanistan  AFG  1986              1.5            0.4
# 41     Afghanistan  AFG  1987              1.6            0.5
# 42     Afghanistan  AFG  1988              1.7            0.5
# ...

# %%
# sort by year the top ten countries for the lastest year of Data recorded 
men_and_women_df.sort_values(by= ['Year', 'Total population'], ascending=False).head(5)
# Out:
#               Entity Code  Year  Obese Women (%)  Obese Men (%)  \
# 3967           China  CHN  2013              5.7            4.8
# 8642           India  IND  2013              4.4            2.3
# 20048  United States  USA  2013             35.1           33.3
# 8841       Indonesia  IDN  2013              7.7            3.8
# 2604          Brazil  BRA  2013             23.9           17.0
#
#        Total population
# 3967       1.359368e+09
# 8642       1.275138e+09
# 20048      3.184976e+08
# 8841       2.471882e+08
# 2604       2.000505e+08

# %%
#Make a barchart to show the percentage of obese men vs women 
men_means, men_std = (5, 3, 33, 4, 17), (2, 3, 4, 1, 2)
women_means, women_std = (6, 4, 35, 8, 24), (3, 5, 2, 3, 3)

# the x locations for the groups
ind = np.arange(len(men_means))  
width = 0.35  # the width of the bars


fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, men_means, width, yerr=men_std,
                color='Skyblue', label='Men')
rects2 = ax.bar(ind + width/2, women_means, width, yerr=women_std,
                color='Pink', label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Average Weight')
ax.set_title('Obesity among Men vs Women')
ax.set_xlabel('Countries')
def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(height), ha=ha[xpos], va='bottom')


autolabel(rects1, "left")
autolabel(rects2, "right")

plt.show()
